# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %% [markdown]
# ### Cargamos el dataset

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Eliminamos las columnas que no son predicturas

# %%
df = df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'])

# %% [markdown]
# Creamos cageogoricas

# %%
df = pd.get_dummies(df)
del df['Sex_female']
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_C  \
# 0         0       3  22.0      1      0   7.2500      True       False
# 1         1       1  38.0      1      0  71.2833     False        True
# 2         1       3  26.0      0      0   7.9250     False       False
# 3         1       1  35.0      1      0  53.1000     False       False
# 4         0       3  35.0      0      0   8.0500      True       False
#
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False       False
# 2       False        True
# 3       False        True
# 4       False        True

# %% [markdown]
# ### Pequeña exploración de datos

# %%
df.groupby('Survived').mean()
# Out:
#             Pclass        Age     SibSp     Parch       Fare  Sex_male  \
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887  0.852459
# 1         1.950292  28.343690  0.473684  0.464912  48.395408  0.318713
#
#           Embarked_C  Embarked_Q  Embarked_S
# Survived
# 0           0.136612    0.085610    0.777778
# 1           0.271930    0.087719    0.634503

# %% [markdown]
# Quitamos los NA's

# %%
df.isna().mean()
# Out:
# Survived      0.000000
# Pclass        0.000000
# Age           0.198653
# SibSp         0.000000
# Parch         0.000000
# Fare          0.000000
# Sex_male      0.000000
# Embarked_C    0.000000
# Embarked_Q    0.000000
# Embarked_S    0.000000
# dtype: float64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %% [markdown]
# ### Crea un modelo

# %%
target = 'Survived'
X = df.drop(target, axis=1)
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
# Out:
# c:\Users\epile\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ## Predicciones del modelo, cuales son los tipos que hay

# %%
probas = model.predict_proba(X_test)

probabilidades = [i[1] for i in probas]
predicciones = model.predict(X_test)

calibracion = pd.DataFrame({
    'target': y_test,
    'probabilidades': probabilidades,
    'predicciones': predicciones
})

calibracion
# Out:
#      target  probabilidades  predicciones
# 495       0        0.207432             0
# 648       0        0.117217             0
# 278       0        0.075825             0
# 31        1        0.938704             1
# 255       1        0.708300             1
# ..      ...             ...           ...
# 263       0        0.364247             0
# 718       0        0.143332             0
# 620       0        0.167833             0
# 786       1        0.699103             1
# 64        0        0.626900             1
#
# [268 rows x 3 columns]

# %% [markdown]
# ### Calibracion

# %%
calibracion['bins'] = pd.qcut(calibracion['probabilidades'], q=10, labels=False) +1

grouped = calibracion.groupby('bins').mean()

# %%
plt.figure(figsize=(8, 6))
plt.plot(grouped['probabilidades'], grouped['probabilidades'], label='real', color='red')
plt.plot(grouped['probabilidades'], grouped['target'], marker='o', label='modelo', color='cadetblue')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### ¿Qué tanto le atina?

# %%
np.mean(calibracion['predicciones'] == calibracion['target'])
# Out:
# 0.8022388059701493

# %% [markdown]
# Con sklearn

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_pred=calibracion['predicciones'], y_true=calibracion['target'])
# Out:
# 0.8022388059701493

# %% [markdown]
# ###  Histogramas

# %%
prob_1 = calibracion[calibracion['target'] == 1]['probabilidades']
prob_2 = calibracion[calibracion['target'] == 0]['probabilidades']

# %%
plt.figure(figsize=(8, 6))
plt.hist(prob_1, alpha=0.5, density=True,  label='Sobrevive', bins = 30)
plt.hist(prob_2, alpha=0.5, density=True,  label='Muere',  bins = 30)
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Usando statsmodel

# %%
import statsmodels.formula.api as smf
df = pd.read_csv('titanic.csv')

# %%
df = df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)

# %%
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
model = smf.logit('Survived ~ C(Pclass) + C(Sex) + Age + SibSp + Parch + Fare + C(Embarked)', data=df).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.444060
#          Iterations 6

# %%
model.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
